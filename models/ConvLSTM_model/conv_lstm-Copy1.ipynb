# %% [markdown]
# # ConvLSTM model

# %% [markdown]
# Import libraries and modules.

# %%
# %cd ..
# %cd ..
# move to the root directory of the git
# Out:
# /workspace/FLOOD_group2/models
# /workspace/FLOOD_group2

# %%
import importlib
import joblib
import torch
import copy

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import torch.nn as nn

# Enable interactive widgets in Jupyter Notebook
# %matplotlib widget

# import torch.nn.functional as F
from torchsummary import summary
from torch.utils.data.dataset import random_split
from torch.utils.data import DataLoader
from mpl_toolkits.axes_grid1 import make_axes_locatable
from torch.optim.lr_scheduler import StepLR

from models.ConvLSTM_model.ConvLSTM_pytorch.multistep_convlstm import MultiStepConvLSTM
from models.ConvLSTM_model.ConvLSTM_pytorch.convlstm import ConvLSTM
from models.ConvLSTM_model.train_eval import train_epoch_conv_lstm, evaluation_conv_lstm
from pre_processing.encode_decode_csv import decode_from_csv
from pre_processing.normalization import * 
from post_processing.cool_animation import plot_animation
from post_processing.plots import plot_losses

# %%
# model save path
save_path = 'models/ConvLSTM_model/model_paths/multiconv_lstm_4hid_8lay_5ker_duplicate.pth'

# if using a "simple" ConvLSTM model uncomment the following line and comment the one above
# save_path = 'models/ConvLSTM_model/conv_lstm_16batch_32hidden_48layers.pth'

# %% [markdown]
# Check if GPU is available.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# The following lines create variables to more easily specify what we use the model for (i.e., train and validate, test with dataset 1 and so on) in the following functions.

# %%
train_val = 'train_val'
test1 = 'test1'
test2 = 'test2'
test3 = 'test3'

# %% [markdown]
# Load data from decoder.

# %% [markdown]
# **Please note**:
# \
# inputs and targets in <code>train_val</code> are not stored in the original manner.
#
# index 0 = 1, index 1 = 10, index 11 = 2, index 12 = 20 etc.

# %%
# training and validation dataset
train_dataset = decode_from_csv(train_val)
# Out:
# Restored inputs Shape: torch.Size([80, 1, 4, 64, 64])
# Restored targets Shape: torch.Size([80, 48, 2, 64, 64])

# %%
# From FAT application
fig, axs = plt.subplots(1, 4, figsize=(10, 5))

# specify which entry of the dataset to plot
numb = 0
inputs = train_dataset[numb][0][0]

axs[0].imshow(inputs[0].cpu(), cmap='terrain', origin='lower')
axs[0].set_title('DEM')

axs[1].imshow(inputs[1].cpu(), cmap='RdBu', origin='lower')
axs[1].set_title('Slope X')

axs[2].imshow(inputs[2].cpu(), cmap='RdBu', origin='lower')
axs[2].set_title('Slope Y')

non_zero_indices = torch.nonzero(inputs[3].cpu())
non_zero_row, non_zero_col = non_zero_indices[0][0].item(), non_zero_indices[0][1].item()
axs[3].imshow(inputs[3].cpu(), cmap='binary', origin='lower')
axs[3].set_title('Breach Location')
axs[3].scatter(non_zero_col, non_zero_row, color='k', marker='x', s=100,
                clip_on = False, clip_box = plt.gca().transData)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Split dataset into train and validation
train_percnt = 0.8
train_size = int(train_percnt * len(train_dataset))
val_size = len(train_dataset) - train_size
train_set, val_set = random_split(train_dataset, [train_size, val_size])

# %%
# Normalize the inputs and outputs using training dataset
scaler_x, scaler_y = scaler(train_set)

normalized_train_dataset = normalize_dataset(train_set, scaler_x, scaler_y, train_val)
normalized_val_dataset = normalize_dataset(val_set, scaler_x, scaler_y, train_val)

# %%
## save scalers for use in seperate notebooks on testing
joblib.dump(scaler_x, 'models/ConvLSTM_model/scalers/scaler_x.joblib')
joblib.dump(scaler_y, 'models/ConvLSTM_model/scalers/scaler_y.joblib');

# %%
# Model
model = MultiStepConvLSTM(input_dim = normalized_train_dataset[0][0].shape[1],
                          output_dim = normalized_train_dataset[0][1].shape[1], 
                          hidden_dim = 4, kernel_size = (5, 5), num_layers = 8,
                          batch_first=True, bias=True, return_all_layers = False).to(device)

# if using a "simple" ConvLSTM model uncomment the following line and comment the ones above
# model = ConvLSTM(input_dim = normalized_train_dataset[0][0].shape[1], output_dim = normalized_train_dataset[0][1].shape[1], hidden_dim = 32, kernel_size = (3, 3),
#                  num_layers = 48, batch_first=True, bias=True, return_all_layers = True).to(device)

# %%
model
# why are there 4 less cells states in the Conv2D (?) - possible question for the presentation, from Roberto
# Out:
# MultiStepConvLSTM(
#   (conv2): Conv2d(4, 2, kernel_size=(1, 1), stride=(1, 1))
#   (cell_list): ModuleList(
#     (0-7): 8 x ConvLSTMCell(
#       (conv): Conv2d(8, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
# )

# %%
num_parameters = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {num_parameters}")
model_size_MB = num_parameters * 4 / (1024 ** 2)  # Assuming float32 precision
print(f"Model size: {model_size_MB:.2f} MB")
# Out:
# Number of parameters: 25738
# Model size: 0.10 MB

# %%
# Set training parameters
learning_rate = 0.00005
batch_size = 16 # Only have 64 and 16 samples for training and validation, I think should be kept small, having issues where this only works if set to 1
num_epochs = 1500

# Create the optimizer to train the neural network via back-propagation
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
# Create scheduler for decreasing the learning rate every 50 epochs with a factor 0.9
scheduler = StepLR(optimizer, step_size = 25, gamma = 0.9, verbose=True)

# Create the training and validation dataloaders to "feed" data to the model in batches
train_loader = DataLoader(normalized_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(normalized_val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-05.

# %%
train_losses = []
val_losses = []
count = 0
for epoch in range(1, num_epochs+1):
    # print(f"epoch number: {epoch}")
    # Model training
    train_loss = train_epoch_conv_lstm(model, train_loader, optimizer, device)

    # Model validation
    val_loss = evaluation_conv_lstm(model, val_loader, device)

    if epoch == 1:
        best_loss = val_loss
    
    if val_loss<=best_loss:
        best_model = copy.deepcopy(model)
        best_loss = val_loss
        best_epoch = epoch
        count = 0

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    count += 1
    if epoch%10 == 0:
        print(f"Epoch: {epoch} " +
              f"\t Training loss: {train_loss: .2e} " + 
              f"\t Validation loss: {val_loss: .2e} " +
              f"\t Best validation loss: {best_loss: .2e}")
    stop_count = 150
    if count > stop_count:
        print(f"Loss Stagnated for {stop_count} epochs, early stopping initiated")
        break
# Out:
# Epoch: 10 	 Training loss:  6.44e-03 	 Validation loss:  5.75e-03 	 Best validation loss:  5.75e-03
# Epoch: 20 	 Training loss:  3.86e-03 	 Validation loss:  3.88e-03 	 Best validation loss:  3.88e-03
# Epoch: 30 	 Training loss:  3.75e-03 	 Validation loss:  3.79e-03 	 Best validation loss:  3.79e-03
# Epoch: 40 	 Training loss:  3.68e-03 	 Validation loss:  3.72e-03 	 Best validation loss:  3.72e-03
# Epoch: 50 	 Training loss:  3.62e-03 	 Validation loss:  3.66e-03 	 Best validation loss:  3.66e-03
# Epoch: 60 	 Training loss:  3.55e-03 	 Validation loss:  3.59e-03 	 Best validation loss:  3.59e-03
# Epoch: 70 	 Training loss:  3.48e-03 	 Validation loss:  3.53e-03 	 Best validation loss:  3.53e-03
# Epoch: 80 	 Training loss:  3.41e-03 	 Validation loss:  3.46e-03 	 Best validation loss:  3.46e-03
# Epoch: 90 	 Training loss:  3.33e-03 	 Validation loss:  3.38e-03 	 Best validation loss:  3.38e-03
# Epoch: 100 	 Training loss:  3.24e-03 	 Validation loss:  3.29e-03 	 Best validation loss:  3.29e-03
# Epoch: 110 	 Training loss:  3.08e-03 	 Validation loss:  3.13e-03 	 Best validation loss:  3.13e-03
# Epoch: 120 	 Training loss:  2.80e-03 	 Validation loss:  2.84e-03 	 Best validation loss:  2.84e-03
# Epoch: 130 	 Training loss:  2.60e-03 	 Validation loss:  2.62e-03 	 Best validation loss:  2.62e-03
# Epoch: 140 	 Training loss:  2.51e-03 	 Validation loss:  2.52e-03 	 Best validation loss:  2.52e-03
# Epoch: 150 	 Training loss:  2.43e-03 	 Validation loss:  2.43e-03 	 Best validation loss:  2.43e-03
# Epoch: 160 	 Training loss:  2.37e-03 	 Validation loss:  2.36e-03 	 Best validation loss:  2.36e-03
# Epoch: 170 	 Training loss:  2.31e-03 	 Validation loss:  2.30e-03 	 Best validation loss:  2.30e-03
# Epoch: 180 	 Training loss:  2.25e-03 	 Validation loss:  2.25e-03 	 Best validation loss:  2.25e-03
# Epoch: 190 	 Training loss:  2.20e-03 	 Validation loss:  2.21e-03 	 Best validation loss:  2.21e-03
# Epoch: 200 	 Training loss:  2.16e-03 	 Validation loss:  2.17e-03 	 Best validation loss:  2.17e-03
# Epoch: 210 	 Training loss:  2.11e-03 	 Validation loss:  2.11e-03 	 Best validation loss:  2.11e-03
# Epoch: 220 	 Training loss:  2.07e-03 	 Validation loss:  2.06e-03 	 Best validation loss:  2.06e-03
# Epoch: 230 	 Training loss:  2.02e-03 	 Validation loss:  2.02e-03 	 Best validation loss:  2.02e-03
# Epoch: 240 	 Training loss:  1.99e-03 	 Validation loss:  1.98e-03 	 Best validation loss:  1.98e-03
# Epoch: 250 	 Training loss:  1.98e-03 	 Validation loss:  1.96e-03 	 Best validation loss:  1.96e-03
# Epoch: 260 	 Training loss:  1.95e-03 	 Validation loss:  1.93e-03 	 Best validation loss:  1.93e-03
# Epoch: 270 	 Training loss:  1.93e-03 	 Validation loss:  1.92e-03 	 Best validation loss:  1.92e-03
# Epoch: 280 	 Training loss:  1.91e-03 	 Validation loss:  1.90e-03 	 Best validation loss:  1.90e-03
# Epoch: 290 	 Training loss:  1.90e-03 	 Validation loss:  1.88e-03 	 Best validation loss:  1.88e-03
# Epoch: 300 	 Training loss:  1.89e-03 	 Validation loss:  1.88e-03 	 Best validation loss:  1.87e-03
# Epoch: 310 	 Training loss:  1.90e-03 	 Validation loss:  1.92e-03 	 Best validation loss:  1.86e-03
# Epoch: 320 	 Training loss:  1.85e-03 	 Validation loss:  1.85e-03 	 Best validation loss:  1.85e-03
# Epoch: 330 	 Training loss:  1.84e-03 	 Validation loss:  1.83e-03 	 Best validation loss:  1.83e-03
# Epoch: 340 	 Training loss:  1.84e-03 	 Validation loss:  1.83e-03 	 Best validation loss:  1.83e-03
# Epoch: 350 	 Training loss:  1.82e-03 	 Validation loss:  1.82e-03 	 Best validation loss:  1.81e-03
# Epoch: 360 	 Training loss:  1.82e-03 	 Validation loss:  1.80e-03 	 Best validation loss:  1.80e-03
# Epoch: 370 	 Training loss:  1.81e-03 	 Validation loss:  1.80e-03 	 Best validation loss:  1.80e-03
# Epoch: 380 	 Training loss:  1.80e-03 	 Validation loss:  1.78e-03 	 Best validation loss:  1.78e-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       3 count = 0
#       4 for epoch in range(1, num_epochs+1):
#       5     # print(f"epoch number: {epoch}")
#       6     # Model training
# ----> 7     train_loss = train_epoch_conv_lstm(model, train_loader, optimizer, device)
#       9     # Model validation
#      10     val_loss = evaluation_conv_lstm(model, val_loader, device)
#
# File /workspace/FLOOD_group2/models/ConvLSTM_model/train_eval.py:75, in train_epoch_conv_lstm(model, loader, optimizer, device)
#      72 losses.append(loss.cpu().detach())
#      74 # Backpropagate and update weights
# ---> 75 loss.backward()   # compute the gradients using backpropagation
#      76 optimizer.step()  # update the weights with the optimizer
#      77 optimizer.zero_grad(set_to_none=True)   # reset the computed gradients
#
# File /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
model = copy.deepcopy(best_model)
torch.save(model.state_dict(), save_path)

# %%
plot_losses(train_losses, val_losses, model)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_animation(10, normalized_val_dataset, model, train_val,
               scaler_x, scaler_y, device = device, save = False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
